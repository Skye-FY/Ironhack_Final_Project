# %%
y(t) = Level * Trend * Seasonality * Noise

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Total population, N.
N = 1000
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = 1, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0
# Contact rate, beta, and mean recovery rate, gamma, (in 1/days).
beta, gamma = 0.2, 1./10 
# A grid of time points (in days)
t = np.linspace(0, 160, 160)

# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(N, beta, gamma))
S, I, R = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, axisbelow=True)
ax.plot(t, S/1000, 'b', alpha=0.5, lw=2, label='Susceptible')
ax.plot(t, I/1000, 'r', alpha=0.5, lw=2, label='Infected')
ax.plot(t, R/1000, 'g', alpha=0.5, lw=2, label='Recovered with immunity')
ax.set_xlabel('Time /days')
ax.set_ylabel('Number (1000s)')
ax.set_ylim(0,1.2)
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(b=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()

# %%
import pandas as pd
pd.set_option('display.max_columns',None)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sars = pd.read_csv('../data/sars_chn_agg.csv')

# %%
sars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2538 entries, 0 to 2537
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Date                          2538 non-null   object
#  1   Country                       2538 non-null   object
#  2   Cumulative_Number_Of_Case(s)  2538 non-null   int64
#  3   Number_Of_Deaths              2538 non-null   int64
#  4   Number_Recovered              2538 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 99.3+ KB

# %%
b = sars.set_index('Date')
b.plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
b['Number_Of_Deaths'].plot(figsize=(20,10), linewidth=5, fontsize=20)
plt.xlabel('Date', fontsize=20)
# Out:
# Text(0.5, 0, 'Date')

# %%
c = sars.groupby('Date').agg({'Cumulative_Number_Of_Case(s)':'sum','Number_Of_Deaths':'sum','Number_Recovered':'sum'})

# %%
c
# Out:
#          Date  Cumulative_Number_Of_Case(s)  Number_Of_Deaths  \
# 0   3/17/2003                           167                 4
# 1   3/18/2003                           386                 4
# 2   3/19/2003                           650                 9
# 3   3/20/2003                           956                10
# 4   3/21/2003                          1306                10
# ..        ...                           ...               ...
# 91   7/3/2003                        522630               812
# 92   7/4/2003                        531064               812
# 93   7/7/2003                        539498               812
# 94   7/8/2003                        547929               812
# 95   7/9/2003                        556360               812
#
#     Number_Recovered
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 91              7422
# 92              7426
# 93              7426
# 94              7428
# 95              7438
#
# [96 rows x 4 columns]

# %%
c.plot()

# %%
c.reset_index(inplace=True)

# %%
sars.groupby(['Date']).agg('sum').plot()

# %%
ct = c['Cumulative_Number_Of_Case(s)']
cd = c['Number_Of_Deaths']
ce = c['Number_Recovered']

# %%
daily_cases = ct.diff().fillna(ct[0]).astype(np.int64)
daily_cases.head()
# Out:
# 0    167
# 1    219
# 2    264
# 3    306
# 4    350
# Name: Cumulative_Number_Of_Case(s), dtype: int64

# %%
plt.plot(daily_cases)
plt.title("Daily cases");

# %%
X = c[['Cumulative_Number_Of_Case(s)', 'Number_Of_Deaths']]
y =

# %%
from statsmodels.tsa.stattools import adfuller
dftest = adfuller(c['Cumulative_Number_Of_Case(s)'], autolag='AIC')
dftest[1]
# Out:
# 0.9917082388603854

# %%
from statsmodels.tsa.stattools import acf, pacf
ACF = acf(c['Cumulative_Number_Of_Case(s)'], nlags=1)
PACF = pacf(c['Cumulative_Number_Of_Case(s)'], nlags=1, method='ols')
print(ACF)
print(PACF)
# Out:
# [1.         0.97157986]
# [1.         1.01359827]

# %%
from pandas import Series
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = c['Cumulative_Number_Of_Case(s)'].astype(float)
plot_acf(series)
pyplot.show()
timeSeriesData = c['Cumulative_Number_Of_Case(s)']
train = timeSeriesData[:int(0.9*(len(timeSeriesData)))]
test = timeSeriesData[int(0.9*(len(timeSeriesData))):]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
plt.plot(train)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
plt.plot(train[1:100])

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(d[['index','Cumulative_Number_Of_Ctase(s)']])

# %%
autocorrelation_plot(d[['index','Cumulative_Number_Of_Case(s)','Number_Recovered','Number_Of_Deaths']])

# %%
d= c.reset_index()

# %%
a = d[d.columns[2]].diff()

# %%
plt.plot(a.diff())

# %%
ArimaModel = ARIMA(d[['Cumulative_Number_Of_Case(s)']], order=(5,2,2))
ArimaFit = ArimaModel.fit()

# %%
ab = a.diff().fillna(0)
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   index                         96 non-null     int64
#  1   Date                          96 non-null     object
#  2   Cumulative_Number_Of_Case(s)  96 non-null     int64
#  3   Number_Of_Deaths              96 non-null     int64
#  4   Number_Recovered              96 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 3.9+ KB

# %%
ArimaFit.predict(start=len(d['index']), end=len(d['index']-1))
# Out:
# 96    227.499666
# dtype: float64

# %%
d
# Out:
#     index       Date  Cumulative_Number_Of_Case(s)  Number_Of_Deaths  \
# 0       0  3/17/2003                           167                 4
# 1       1  3/18/2003                           386                 4
# 2       2  3/19/2003                           650                 9
# 3       3  3/20/2003                           956                10
# 4       4  3/21/2003                          1306                10
# ..    ...        ...                           ...               ...
# 91     91   7/3/2003                        522630               812
# 92     92   7/4/2003                        531064               812
# 93     93   7/7/2003                        539498               812
# 94     94   7/8/2003                        547929               812
# 95     95   7/9/2003                        556360               812
#
#     Number_Recovered
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 91              7422
# 92              7426
# 93              7426
# 94              7428
# 95              7438
#
# [96 rows x 5 columns]

# %%
import tensorflow as tf

# %%
d = sars.reset_index()

# %%
train = d['Cumulative_Number_Of_Case(s)'][:75]
test = d['Cumulative_Number_Of_Case(s)'][75:]

# %%
X_train = tf.keras.utils.normalize(train, axis=1)
X_test = tf.keras.utils.normalize(test, axis=1)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(1,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(28, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(1, activation=tf.nn.softmax))
model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=4)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-11-eba61fc94161> in <module>
# ----> 1 X_train = tf.keras.utils.normalize(train, axis=1)
#       2 X_test = tf.keras.utils.normalize(test, axis=1)
#       3 model = tf.keras.models.Sequential()
#       4 model.add(tf.keras.layers.Dense(1,activation=tf.nn.relu))
#       5 model.add(tf.keras.layers.Dense(28, activation=tf.nn.relu))
#
# ~\Anaconda3\lib\site-packages\tensorflow_core\python\keras\utils\np_utils.py in normalize(x, axis, order)
#      65       A normalized copy of the array.
#      66   """
# ---> 67   l2 = np.atleast_1d(np.linalg.norm(x, order, axis))
#      68   l2[l2 == 0] = 1
#      69   return x / np.expand_dims(l2, axis)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in norm(x, ord, axis, keepdims)
#    2479             # special case for speedup
#    2480             s = (x.conj() * x).real
# -> 2481             return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2482         else:
#    2483             try:
#
# AxisError: axis 1 is out of bounds for array of dimension 1
